# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Car_sales.csv')

# %%
df.value_counts('Vehicle_type')
# Out:
# Vehicle_type
# Passenger    116
# Car           41
# Name: count, dtype: int64

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df_selected=df[["Manufacturer"	,"Sales_in_thousands","Vehicle_type","Price_in_thousands","Engine_size","Horsepower","Fuel_capacity"	]]

# %%
df_selected
# Out:
#     Manufacturer  Sales_in_thousands Vehicle_type  Price_in_thousands  \
# 0          Acura              16.919    Passenger               21.50
# 1          Acura              39.384    Passenger               28.40
# 2          Acura              14.114    Passenger                 NaN
# 3          Acura               8.588    Passenger               42.00
# 4           Audi              20.397    Passenger               23.99
# ..           ...                 ...          ...                 ...
# 152        Volvo               3.545    Passenger               24.40
# 153        Volvo              15.245    Passenger               27.50
# 154        Volvo              17.531    Passenger               28.80
# 155        Volvo               3.493    Passenger               45.50
# 156        Volvo              18.969    Passenger               36.00
#
#      Engine_size  Horsepower  Fuel_capacity
# 0            1.8       140.0           13.2
# ...

# %%
df_selected.nunique()
# Out:
# Manufacturer           30
# Sales_in_thousands    157
# Vehicle_type            2
# Price_in_thousands    152
# Engine_size            31
# Horsepower             66
# Fuel_capacity          55
# dtype: int64

# %%
df_selected.agg('sum')
# Out:
# Manufacturer          AcuraAcuraAcuraAcuraAudiAudiAudiBMWBMWBMWBuick...
# Sales_in_thousands                                             8320.698
# Vehicle_type          PassengerPassengerPassengerPassengerPassengerP...
# Price_in_thousands                                             4245.567
# Engine_size                                                       477.5
# Horsepower                                                      29008.0
# Fuel_capacity                                                    2800.5
# dtype: object

# %%
#calc sum of columns
df_selected.sum()
# Out:
# Manufacturer          AcuraAcuraAcuraAcuraAudiAudiAudiBMWBMWBMWBuick...
# Sales_in_thousands                                             8320.698
# Vehicle_type          PassengerPassengerPassengerPassengerPassengerP...
# Price_in_thousands                                             4245.567
# Engine_size                                                       477.5
# Horsepower                                                      29008.0
# Fuel_capacity                                                    2800.5
# dtype: object

# %%
df_selected.mean(numeric_only=True)
# Out:
# Sales_in_thousands     52.998076
# Price_in_thousands     27.390755
# Engine_size             3.060897
# Horsepower            185.948718
# Fuel_capacity          17.951923
# dtype: float64

# %%
#mean of
df_selected.agg('mean', numeric_only=True)
# Out:
# Sales_in_thousands     52.998076
# Price_in_thousands     27.390755
# Engine_size             3.060897
# Horsepower            185.948718
# Fuel_capacity          17.951923
# dtype: float64

# %%
Sales_in_thousands
Price_in_thousands
Engine_size
Horsepower
Fuel_capacity

# %%
#both function,add them to list and then agg
df_selected[['Sales_in_thousands',

             'Price_in_thousands',

             'Engine_size',

             'Horsepower',

             'Fuel_capacity'	]].apply(['mean','count'])
# Out:
#        Sales_in_thousands  Price_in_thousands  Engine_size  Horsepower  \
# mean            52.998076           27.390755     3.060897  185.948718
# count          157.000000          155.000000   156.000000  156.000000
#
#        Fuel_capacity
# mean       17.951923
# count     156.000000

# %%
#diff agg per coulmns
df_selected.agg({'Sales_in_thousands':['sum','mean'],
                 'Price_in_thousands':['sum','max'] })
# Out:
#       Sales_in_thousands  Price_in_thousands
# sum          8320.698000            4245.567
# mean           52.998076                 NaN
# max                  NaN              85.500

# %%
#agg over columns ,treat nan values as zero
df_selected[['Sales_in_thousands','Price_in_thousands']].agg('sum',axis=1)
# Out:
# 0      38.419
# 1      67.784
# 2      14.114
# 3      50.588
# 4      44.387
#         ...
# 152    27.945
# 153    42.745
# 154    46.331
# 155    48.993
# 156    54.969
# Length: 157, dtype: float64

# %%
#same as but they behave differntly sometimes
df_selected['Sales_in_thousands']+df_selected['Price_in_thousands']
# Out:
# 0      38.419
# 1      67.784
# 2         NaN
# 3      50.588
# 4      44.387
#         ...
# 152    27.945
# 153    42.745
# 154    46.331
# 155    48.993
# 156    54.969
# Length: 157, dtype: float64

# %% [markdown]
# # **the split apply combine strategy
# **

# %%
df_selected.agg(x=('Sales_in_thousands','sum'),
                y=('Price_in_thousands','sum'))
# Out:
#    Sales_in_thousands  Price_in_thousands
# x            8320.698                 NaN
# y                 NaN            4245.567

# %%
passenger_filter=df_selected['Vehicle_type']=='Passenger'
car_filter=df_selected['Vehicle_type']=='Car'
#df_selected['Vehicle_type'].value_counts()

# %%
df_selected[passenger_filter]['Sales_in_thousands']
# Out:
# 0      16.919
# 1      39.384
# 2      14.114
# 3       8.588
# 4      20.397
#         ...
# 152     3.545
# 153    15.245
# 154    17.531
# 155     3.493
# 156    18.969
# Name: Sales_in_thousands, Length: 116, dtype: float64

# %%
Passenger_avg=df_selected[passenger_filter]['Sales_in_thousands'].mean()

# %%
Car_avg=df_selected[car_filter]['Sales_in_thousands'].mean()

# %%
print(Passenger_avg)
print(Car_avg)
# Out:
# 43.234344827586206
# 80.62229268292683

# %%
pd.DataFrame({'Vechile_type':['Car','Passenger'],
              'Sales_in_thousands':[Car_avg,Passenger_avg]})
# Out:
#   Vechile_type  Sales_in_thousands
# 0          Car           80.622293
# 1    Passenger           43.234345

# %%
#group by easier
#group vechile and calc mean
df_selected.groupby('Vehicle_type').mean(numeric_only=True)
# Out:
#               Sales_in_thousands  Price_in_thousands  Engine_size  Horsepower  \
# Vehicle_type
# Car                    80.622293           26.319975     3.520000  186.400000
# Passenger              43.234345           27.763200     2.902586  185.793103
#
#               Fuel_capacity
# Vehicle_type
# Car               21.895000
# Passenger         16.592241

# %%
#gropu by manufacture
groupby_obj=df_selected.groupby('Manufacturer')

# %%
groupby_obj.groups.keys()
# Out:
# dict_keys(['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet', 'Chrysler', 'Dodge', 'Ford', 'Honda', 'Hyundai', 'Infiniti', 'Jaguar', 'Jeep', 'Lexus', 'Lincoln', 'Mercedes-B', 'Mercury', 'Mitsubishi', 'Nissan', 'Oldsmobile', 'Plymouth', 'Pontiac', 'Porsche', 'Saab', 'Saturn', 'Subaru', 'Toyota', 'Volkswagen', 'Volvo'])

# %%
#get specific group
groupby_obj.get_group('Ford')
# Out:
#    Manufacturer  Sales_in_thousands Vehicle_type  Price_in_thousands  \
# 46         Ford              70.227    Passenger              12.070
# 47         Ford             113.369    Passenger              21.560
# 48         Ford              35.068    Passenger              17.035
# 49         Ford             245.815    Passenger              17.885
# 50         Ford             175.670    Passenger              12.315
# 51         Ford              63.403    Passenger              22.195
# 52         Ford             276.747          Car              31.930
# 53         Ford             155.787          Car              21.410
# 54         Ford             125.338          Car              36.135
# 55         Ford             220.650          Car              12.050
# 56         Ford             540.561          Car              26.935
#
#     Engine_size  Horsepower  Fuel_capacity
# 46          2.0       110.0           12.7
# 47          3.8       190.0           15.7
# ...

# %%
df_selected.groupby('Manufacturer').mean(numeric_only=True)
# Out:
#               Sales_in_thousands  Price_in_thousands  Engine_size  Horsepower  \
# Manufacturer
# Acura                  19.751250           30.633333     2.925000  200.000000
# Audi                   13.519000           39.980000     2.933333  220.000000
# BMW                    15.501667           33.096667     2.700000  185.333333
# Buick                  60.504750           26.781250     3.625000  206.250000
# Cadillac               22.435600           40.254000     4.500000  256.000000
# Chevrolet              61.596111           20.022778     3.055556  171.111111
# Chrysler               28.817286           23.430833     2.783333  194.833333
# Dodge                  82.740818           24.213636     3.709091  199.545455
# Ford                  183.875909           21.047273     3.327273  170.090909
# Honda                 118.534800           20.277000     2.520000  160.400000
# Hyundai                45.775333           12.165667     1.966667  126.666667
# ...

# %%
df_selected.groupby('Manufacturer').sum(numeric_only=True)
# Out:
#               Sales_in_thousands  Price_in_thousands  Engine_size  Horsepower  \
# Manufacturer
# Acura                     79.005              91.900         11.7       800.0
# Audi                      40.557             119.940          8.8       660.0
# BMW                       46.505              99.290          8.1       556.0
# Buick                    242.019             107.125         14.5       825.0
# Cadillac                 112.178             201.270         22.5      1280.0
# Chevrolet                554.365             180.205         27.5      1540.0
# Chrysler                 201.721             140.585         16.7      1169.0
# Dodge                    910.149             266.350         40.8      2195.0
# Ford                    2022.635             231.520         36.6      1871.0
# Honda                    592.674             101.385         12.6       802.0
# Hyundai                  137.326              36.497          5.9       380.0
# ...

# %%
df_selected.groupby('Vehicle_type').count() #doesnt count nan values
# Out:
#               Manufacturer  Sales_in_thousands  Price_in_thousands  \
# Vehicle_type
# Car                     41                  41                  40
# Passenger              116                 116                 115
#
#               Engine_size  Horsepower  Fuel_capacity
# Vehicle_type
# Car                    40          40             40
# Passenger             116         116            116

# %%
df_selected.isnull().sum()
# Out:
# Manufacturer          0
# Sales_in_thousands    0
# Vehicle_type          0
# Price_in_thousands    2
# Engine_size           1
# Horsepower            1
# Fuel_capacity         1
# dtype: int64

# %%
df_selected.groupby('Engine_size',dropna=False).count() #to include nan values
# Out:
#              Manufacturer  Sales_in_thousands  Vehicle_type  \
# Engine_size
# 1.0                     1                   1             1
# 1.5                     1                   1             1
# 1.6                     1                   1             1
# 1.8                     8                   8             8
# 1.9                     5                   5             5
# 2.0                    17                  17            17
# 2.2                     4                   4             4
# 2.3                     6                   6             6
# 2.4                    11                  11            11
# 2.5                    11                  11            11
# 2.7                     4                   4             4
# 2.8                     3                   3             3
# 2.9                     1                   1             1
# 3.0                    14                  14            14
# ...

# %%
df_selected.groupby('Vehicle_type').min()
# Out:
#              Manufacturer  Sales_in_thousands  Price_in_thousands  \
# Vehicle_type
# Car              Cadillac               9.126              11.528
# Passenger           Acura               0.110               9.235
#
#               Engine_size  Horsepower  Fuel_capacity
# Vehicle_type
# Car                   2.0       119.0           15.1
# Passenger             1.0        55.0           10.3

# %%
df_selected.groupby('Vehicle_type').max()
# Out:
#              Manufacturer  Sales_in_thousands  Price_in_thousands  \
# Vehicle_type
# Car                Toyota             540.561              60.105
# Passenger           Volvo             247.994              85.500
#
#               Engine_size  Horsepower  Fuel_capacity
# Vehicle_type
# Car                   5.7       300.0           32.0
# Passenger             8.0       450.0           23.7

# %%
#combine both using aggg
df_selected.groupby('Vehicle_type').agg(['min','max'])
# Out:
#              Manufacturer         Sales_in_thousands           \
#                       min     max                min      max
# Vehicle_type
# Car              Cadillac  Toyota              9.126  540.561
# Passenger           Acura   Volvo              0.110  247.994
#
#              Price_in_thousands         Engine_size      Horsepower         \
#                             min     max         min  max        min    max
# Vehicle_type
# Car                      11.528  60.105         2.0  5.7      119.0  300.0
# Passenger                 9.235  85.500         1.0  8.0       55.0  450.0
#
#              Fuel_capacity
#                        min   max
# Vehicle_type
# Car                   15.1  32.0
# Passenger             10.3  23.7

# %%
df_selected.groupby('Vehicle_type').agg(min_eng_size=('Engine_size','min'),
                                        max_eng_size=('Engine_size','max'),
                                         min_horse_power=('Horsepower','min'),
                                      max_horse_power=('Horsepower','max'))
# Out:
#               min_eng_size  max_eng_size  min_horse_power  max_horse_power
# Vehicle_type
# Car                    2.0           5.7            119.0            300.0
# Passenger              1.0           8.0             55.0            450.0

# %%
df_selected.groupby('Manufacturer').agg(	sum_sales=('Sales_in_thousands','sum'),	mean_price=('Price_in_thousands','mean'))
# Out:
#               sum_sales  mean_price
# Manufacturer
# Acura            79.005   30.633333
# Audi             40.557   39.980000
# BMW              46.505   33.096667
# Buick           242.019   26.781250
# Cadillac        112.178   40.254000
# Chevrolet       554.365   20.022778
# Chrysler        201.721   23.430833
# Dodge           910.149   24.213636
# Ford           2022.635   21.047273
# Honda           592.674   20.277000
# Hyundai         137.326   12.165667
# Infiniti         23.713   29.465000
# Jaguar           15.467   42.800000
# Jeep            293.153   20.991667
# Lexus           106.843   44.055000
# Lincoln          85.634   41.690000
# Mercedes-B      117.125   52.916667
# Mercury         237.999   20.748333
# Mitsubishi      180.895   22.167429
# Nissan          399.635   22.360714
# Oldsmobile      178.989   25.622833
# Plymouth         64.001   22.642500
# Pontiac         370.534   22.949167
# Porsche          12.128   62.473333
# ...

# %%
df_selected.groupby('Manufacturer').sum()['Sales_in_thousands']
# Out:
# Manufacturer
# Acura           79.005
# Audi            40.557
# BMW             46.505
# Buick          242.019
# Cadillac       112.178
# Chevrolet      554.365
# Chrysler       201.721
# Dodge          910.149
# Ford          2022.635
# Honda          592.674
# Hyundai        137.326
# Infiniti        23.713
# Jaguar          15.467
# Jeep           293.153
# Lexus          106.843
# Lincoln         85.634
# Mercedes-B     117.125
# Mercury        237.999
# Mitsubishi     180.895
# Nissan         399.635
# Oldsmobile     178.989
# Plymouth        64.001
# Pontiac        370.534
# Porsche         12.128
# Saab            21.306
# Saturn         168.850
# Subaru          80.135
# Toyota         740.205
# Volkswagen     209.212
# Volvo           75.740
# Name: Sales_in_thousands, dtype: float64

# %%
df_selected.groupby('Manufacturer').mean(numeric_only=True)['Price_in_thousands']
# Out:
# Manufacturer
# Acura         30.633333
# Audi          39.980000
# BMW           33.096667
# Buick         26.781250
# Cadillac      40.254000
# Chevrolet     20.022778
# Chrysler      23.430833
# Dodge         24.213636
# Ford          21.047273
# Honda         20.277000
# Hyundai       12.165667
# Infiniti      29.465000
# Jaguar        42.800000
# Jeep          20.991667
# Lexus         44.055000
# Lincoln       41.690000
# Mercedes-B    52.916667
# Mercury       20.748333
# Mitsubishi    22.167429
# Nissan        22.360714
# Oldsmobile    25.622833
# Plymouth      22.642500
# Pontiac       22.949167
# Porsche       62.473333
# Saab          29.610000
# Saturn        14.271000
# Subaru        21.395000
# Toyota        21.982889
# Volkswagen    17.698333
# Volvo         30.933333
# Name: Price_in_thousands, dtype: float64

# %%
#lambda
thousand=lambda x : x*1000

# %%
df_selected.head(3)
# Out:
#   Manufacturer  Sales_in_thousands Vehicle_type  Price_in_thousands  \
# 0        Acura              16.919    Passenger                21.5
# 1        Acura              39.384    Passenger                28.4
# 2        Acura              14.114    Passenger                 NaN
#
#    Engine_size  Horsepower  Fuel_capacity
# 0          1.8       140.0           13.2
# 1          3.2       225.0           17.2
# 2          3.2       225.0           17.2

# %%
df_selected.groupby('Manufacturer').apply(lambda x:x*1000)[['Sales_in_thousands','Price_in_thousands']]
# Out:
# /tmp/ipython-input-1124674106.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_selected.groupby('Manufacturer').apply(lambda x:x*1000)[['Sales_in_thousands','Price_in_thousands']]
#                   Sales_in_thousands  Price_in_thousands
# Manufacturer
# Acura        0               16919.0             21500.0
#              1               39384.0             28400.0
#              2               14114.0                 NaN
#              3                8588.0             42000.0
# Audi         4               20397.0             23990.0
# ...                              ...                 ...
# Volvo        152              3545.0             24400.0
# ...

# %%
df_selected.groupby('Manufacturer').apply(lambda x:x-x.mean(numeric_only=True))
# Out:
# /tmp/ipython-input-1463673899.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_selected.groupby('Manufacturer').apply(lambda x:x-x.mean(numeric_only=True))
#                   Engine_size  Fuel_capacity  Horsepower Manufacturer  \
# Manufacturer
# Acura        0      -1.125000      -3.200000  -60.000000          NaN
#              1       0.275000       0.800000   25.000000          NaN
#              2       0.275000       0.800000   25.000000          NaN
#              3       0.575000       1.600000   10.000000          NaN
# Audi         4      -1.133333      -3.133333  -70.000000          NaN
# ...                       ...            ...         ...          ...
# ...

# %%
df_selected.groupby('Manufacturer').mean(numeric_only=True)
# Out:
#               Sales_in_thousands  Price_in_thousands  Engine_size  Horsepower  \
# Manufacturer
# Acura                  19.751250           30.633333     2.925000  200.000000
# Audi                   13.519000           39.980000     2.933333  220.000000
# BMW                    15.501667           33.096667     2.700000  185.333333
# Buick                  60.504750           26.781250     3.625000  206.250000
# Cadillac               22.435600           40.254000     4.500000  256.000000
# Chevrolet              61.596111           20.022778     3.055556  171.111111
# Chrysler               28.817286           23.430833     2.783333  194.833333
# Dodge                  82.740818           24.213636     3.709091  199.545455
# Ford                  183.875909           21.047273     3.327273  170.090909
# Honda                 118.534800           20.277000     2.520000  160.400000
# Hyundai                45.775333           12.165667     1.966667  126.666667
# ...

# %%
df_selected.head()
# Out:
#   Manufacturer  Sales_in_thousands Vehicle_type  Price_in_thousands  \
# 0        Acura              16.919    Passenger               21.50
# 1        Acura              39.384    Passenger               28.40
# 2        Acura              14.114    Passenger                 NaN
# 3        Acura               8.588    Passenger               42.00
# 4         Audi              20.397    Passenger               23.99
#
#    Engine_size  Horsepower  Fuel_capacity
# 0          1.8       140.0           13.2
# 1          3.2       225.0           17.2
# 2          3.2       225.0           17.2
# 3          3.5       210.0           18.0
# 4          1.8       150.0           16.4

# %%
df_selected.mean(numeric_only=True)
# Out:
# Sales_in_thousands     52.998076
# Price_in_thousands     27.390755
# Engine_size             3.060897
# Horsepower            185.948718
# Fuel_capacity          17.951923
# dtype: float64

# %%
def filter_func(x):
  return x['Sales_in_thousands'].sum()>52.998076

# %%
#filter

df_filtered=df_selected.groupby('Manufacturer').filter(filter_func)

# %%
df_filtered
# Out:
#     Manufacturer  Sales_in_thousands Vehicle_type  Price_in_thousands  \
# 0          Acura              16.919    Passenger              21.500
# 1          Acura              39.384    Passenger              28.400
# 2          Acura              14.114    Passenger                 NaN
# 3          Acura               8.588    Passenger              42.000
# 10         Buick              91.561    Passenger              21.975
# ..           ...                 ...          ...                 ...
# 152        Volvo               3.545    Passenger              24.400
# 153        Volvo              15.245    Passenger              27.500
# 154        Volvo              17.531    Passenger              28.800
# 155        Volvo               3.493    Passenger              45.500
# 156        Volvo              18.969    Passenger              36.000
#
#      Engine_size  Horsepower  Fuel_capacity
# 0            1.8       140.0           13.2
# ...

# %%
df_selected.groupby('Manufacturer').sum()['Sales_in_thousands'].sort_values()
# Out:
# Manufacturer
# Porsche         12.128
# Jaguar          15.467
# Saab            21.306
# Infiniti        23.713
# Audi            40.557
# BMW             46.505
# Plymouth        64.001
# Volvo           75.740
# Acura           79.005
# Subaru          80.135
# Lincoln         85.634
# Lexus          106.843
# Cadillac       112.178
# Mercedes-B     117.125
# Hyundai        137.326
# Saturn         168.850
# Oldsmobile     178.989
# Mitsubishi     180.895
# Chrysler       201.721
# Volkswagen     209.212
# Mercury        237.999
# Buick          242.019
# Jeep           293.153
# Pontiac        370.534
# Nissan         399.635
# Chevrolet      554.365
# Honda          592.674
# Toyota         740.205
# Dodge          910.149
# Ford          2022.635
# Name: Sales_in_thousands, dtype: float64

# %%
df_selected[df_selected['Manufacturer'].isin(['BMW','Audi','Saab'])]
# Out:
#     Manufacturer  Sales_in_thousands Vehicle_type  Price_in_thousands  \
# 4           Audi              20.397    Passenger               23.99
# 5           Audi              18.780    Passenger               33.95
# 6           Audi               1.380    Passenger               62.00
# 7            BMW              19.747    Passenger               26.99
# 8            BMW               9.231    Passenger               33.40
# 9            BMW              17.527    Passenger               38.90
# 127         Saab               9.191    Passenger               33.12
# 128         Saab              12.115    Passenger               26.10
#
#      Engine_size  Horsepower  Fuel_capacity
# 4            1.8       150.0           16.4
# 5            2.8       200.0           18.5
# 6            4.2       310.0           23.7
# 7            2.5       170.0           16.6
# 8            2.8       193.0           16.6
# 9            2.8       193.0           18.5
# ...
