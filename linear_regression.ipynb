# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/Boston House Prices.csv')

# %%
df.head(3)
# Out:
#    Rooms  Distance  Value
# 0  6.575    4.0900   24.0
# 1  6.421    4.9671   21.6
# 2  7.185    4.9671   34.7

# %%
df.describe()
# Out:
#             Rooms    Distance       Value
# count  506.000000  506.000000  506.000000
# mean     6.284634    3.795043   22.532806
# std      0.702617    2.105710    9.197104
# min      3.561000    1.129600    5.000000
# 25%      5.885500    2.100175   17.025000
# 50%      6.208500    3.207450   21.200000
# 75%      6.623500    5.188425   25.000000
# max      8.780000   12.126500   50.000000

# %%
#machine learning ,linear regression
import statsmodels.api as sm

# %%
#dependent var value
#independant var predictor =room or distance
x=df['Rooms']
y=df['Value']

# %%
df.plot(kind='scatter',x='Rooms',y='Value')
# Out:
# <Axes: xlabel='Rooms', ylabel='Value'>

# %%
#add a const
x= sm.add_constant(x)
#fitting the model
LM=sm.OLS(y,x).fit()

# %%
#predict
LM.predict(x)
# Out:
# 0      25.175746
# 1      23.774021
# 2      30.728032
# 3      29.025938
# 4      30.382152
#          ...
# 501    25.339584
# 502    21.034286
# 503    28.825691
# 504    27.169108
# 505    20.215096
# Length: 506, dtype: float64

# %%
#the regression table model good or bad
LM.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Value   R-squared:                       0.484
# Model:                            OLS   Adj. R-squared:                  0.483
# Method:                 Least Squares   F-statistic:                     471.8
# Date:                Sun, 02 Nov 2025   Prob (F-statistic):           2.49e-74
# Time:                        22:11:22   Log-Likelihood:                -1673.1
# No. Observations:                 506   AIC:                             3350.
# Df Residuals:                     504   BIC:                             3359.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -34.6706      2.650    -13.084      0.000     -39.877     -29.465
# ...

# %%
y_pred=	9.1021*x['Rooms']-34.6706

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4),tight_layout=True)
sns.scatterplot(x=x['Rooms'],y=y)

sns.lineplot(x=x['Rooms'],y=y_pred,color='red')

plt.xlim(0)
plt.ylim(0)
plt.savefig('linearregression')
plt.show()

# %%
#multiple linear reg
#dep=value
Y=df['Value']
#indep=room,distance
X=df[['Rooms','Distance']]

# %%
#add constant
X=sm.add_constant(X)
#fiting
lm=sm.OLS(Y,X).fit()

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Value   R-squared:                       0.496
# Model:                            OLS   Adj. R-squared:                  0.494
# Method:                 Least Squares   F-statistic:                     247.0
# Date:                Sun, 02 Nov 2025   Prob (F-statistic):           1.84e-75
# Time:                        22:17:59   Log-Likelihood:                -1667.1
# No. Observations:                 506   AIC:                             3340.
# Df Residuals:                     503   BIC:                             3353.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -34.6361      2.621    -13.212      0.000     -39.786     -29.486
# ...

# %%
#using sklearn
from sklearn import linear_model

# %%
_Y=df['Value']
_X=df[['Rooms','Distance']]

# %%
_LM=linear_model.LinearRegression()
_LM.fit(_X,_Y)
# Out:
# LinearRegression()

# %%
_LM.predict(_X)[:5]
# Out:
# array([25.23262311, 24.30597474, 31.03025338, 29.9197274 , 31.23113776])

# %%
_LM.score(_X,_Y)
# Out:
# 0.4955246476058477

# %%
_LM.coef_
# Out:
# array([8.80141183, 0.48884854])

# %%
_LM.intercept_
# Out:
# np.float64(-34.636050175473315)
